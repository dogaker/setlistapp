# %%
import json
import urllib2
import csv
import sys
import pandas as pd
from pandas.io.json import json_normalize
from lxml import etree
from lxml import objectify
from io import StringIO, BytesIO

# %%
# Call Setlist.fm API
# response = urllib2.urlopen('http://api.setlist.fm/rest/0.1/artist/' + 'cc197bad-dc9c-440d-a5b5-d52ba2e14234' + '/setlists?p=1')
setlist = urllib2.urlopen('http://api.setlist.fm/rest/0.1/setlist/3d2d1ef')

# %%
setree = etree.parse(setlist)
print etree.tostring(setree, pretty_print = True)
# Out:
# <setlist eventDate="01-06-2004" id="3d2d1ef" lastUpdated="2015-10-10T03:44:31.000+0000" tour="A Reality Tour" versionId="4bbfff1e">
#   <artist disambiguation="" mbid="5441c29d-3602-4898-b1a1-b77fa23b8e50" name="David Bowie" sortName="Bowie, David" tmid="734626">
#     <url>http://www.setlist.fm/setlists/david-bowie-6bd6ee66.html</url>
#   </artist>
#   <venue id="1bd63950" name="Verizon Wireless Arena">
#     <city id="5089178" name="Manchester" state="New Hampshire" stateCode="NH">
#       <coords lat="42.9956397" long="-71.4547891"/>
#       <country code="US" name="United States"/>
#     </city>
#     <url>http://www.setlist.fm/venue/verizon-wireless-arena-manchester-nh-usa-1bd63950.html</url>
#   </venue>
#   <sets>
#     <set>
#       <song name="Rebel Rebel"/>
#       <song name="Queen Bitch"/>
#       <song name="Cactus">
#         <cover disambiguation="" mbid="b6b2bb8d-54a9-491f-9607-7b546023b433" name="Pixies" sortName="Pixies" tmid="906179">
# ...

# %%
root = setree.getroot()
root
# Out:
# <Element setlist at 0x10b597290>

# %%
root.getchildren()
# Out:
# [<Element artist at 0x10b90aa70>,
#  <Element venue at 0x10b90a638>,
#  <Element sets at 0x10b90ac20>,
#  <Element url at 0x10b538908>]

# %%
data = []
for child in root.getchildren():
    n = 1
    if child.tag == 'venue':
        print 'venue:', child.get('name')
    if child.tag == 'artist':
        print 'artist:', child.get('name')
    if child.tag == 'sets':
        for set in child.getchildren():
            for song in set.getchildren():
                if n > 9:
                    print str(n) + ".", song.get('name')
                    n += 1
                else:
                    print "0" + str(n) + ".", song.get('name')
                    n += 1
# Out:
# artist: David Bowie
# venue: Verizon Wireless Arena
# 01. Rebel Rebel
# 02. Queen Bitch
# 03. Cactus
# 04. Sister Midnight
# 05. New Killer Star
# 06. All the Young Dudes
# 07. China Girl
# 08. The Loneliest Guy
# 09. The Man Who Sold the World
# 10. Battle for Britain (The Letter)
# 11. Pablo Picasso
# 12. Heathen (The Rays)
# 13. The Supermen
# 14. Hallo Spaceboy
# 15. Under Pressure
# 16. Station to Station
# 17. Ashes to Ashes
# 18. Quicksand
# 19. Modern Love
# 20. I'm Afraid of Americans
# 21. "Heroes"
# 22. Diamond Dogs
# 23. Five Years
# 24. Suffragette City
# 25. Ziggy Stardust

# %%
data = []
for child in root.getchildren():
    n = 1
    if child.tag == 'venue':
#         print 'venue:', child.get('name')
        venue = [child.get('name')]
    if child.tag == 'artist':
#         print 'artist:', child.get('name')
        artist = [child.get('name')]
    if child.tag == 'sets':
        for set in child.getchildren():
            for song in set.getchildren():
                if n > 9:
                    print "artist: " + str(artist), "venue: " + str(venue), str(n) + ".", song.get('name')
                    n += 1
                else:
                    print "0" + str(n) + ".", song.get('name')
                    n += 1
# Out:
# 01. Rebel Rebel
# 02. Queen Bitch
# 03. Cactus
# 04. Sister Midnight
# 05. New Killer Star
# 06. All the Young Dudes
# 07. China Girl
# 08. The Loneliest Guy
# 09. The Man Who Sold the World
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 10. Battle for Britain (The Letter)
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 11. Pablo Picasso
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 12. Heathen (The Rays)
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 13. The Supermen
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 14. Hallo Spaceboy
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 15. Under Pressure
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 16. Station to Station
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 17. Ashes to Ashes
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 18. Quicksand
# artist: ['David Bowie'] venue: ['Verizon Wireless Arena'] 19. Modern Love
# ...

# %%
data
# Out:
# []

# %%
parser = etree.XMLParser(ns_clean=True)
tree = etree.parse(StringIO(setlist), parser)
etree.tostring(tree.getroot())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-3db895969ec2> in <module>()
#       1 parser = etree.XMLParser(ns_clean=True)
# ----> 2 tree = etree.parse(StringIO(setlist), parser)
#       3 etree.tostring(tree.getroot())
#
# TypeError: initial_value must be unicode or None, not instance

# %%
setree = etree.parse(unicode(setlist))
print etree.tostring(setree, pretty_print = True)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-71-fda70e299244> in <module>()
# ----> 1 setree = etree.parse(unicode(setlist))
#       2 print etree.tostring(setree, pretty_print = True)
#
# lxml.etree.pyx in lxml.etree.parse (src/lxml/lxml.etree.c:72517)()
#
# parser.pxi in lxml.etree._parseDocument (src/lxml/lxml.etree.c:105979)()
#
# parser.pxi in lxml.etree._parseDocumentFromURL (src/lxml/lxml.etree.c:106278)()
#
# parser.pxi in lxml.etree._parseDocFromFile (src/lxml/lxml.etree.c:105277)()
#
# parser.pxi in lxml.etree._BaseParser._parseDocFromFile (src/lxml/lxml.etree.c:100227)()
#
# parser.pxi in lxml.etree._ParserContext._handleParseResultDoc (src/lxml/lxml.etree.c:94350)()
#
# parser.pxi in lxml.etree._handleParseResult (src/lxml/lxml.etree.c:95786)()
#
# parser.pxi in lxml.etree._raiseParseError (src/lxml/lxml.etree.c:94818)()
#
# ...

# %%
root = etree.fromstring(parsed)
etree.tostring(root)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e372239fc94a> in <module>()
# ----> 1 root = etree.fromstring(parsed)
#       2 etree.tostring(root)
#
# lxml.etree.pyx in lxml.etree.fromstring (src/lxml/lxml.etree.c:70569)()
#
# parser.pxi in lxml.etree._parseMemoryDocument (src/lxml/lxml.etree.c:106392)()
#
# ValueError: can only parse strings

# %%
root.findall('setlist')
# Out:
# []

# %%
data = []

for elt in root.findall('setlist'):
    setlist_data = {}
    for child in elt.getchildren():
        setlist_data[child.tag] = child.pyval
    data.append(setlist_data)

# %%
data
# Out:
# []

# %%
setree = etree.parse(setlist)
print etree.tostring(setree, pretty_print = True)
# Out:
# <setlist eventDate="01-06-2004" id="3d2d1ef" lastUpdated="2015-10-10T03:44:31.000+0000" tour="A Reality Tour" versionId="4bbfff1e">
#   <artist disambiguation="" mbid="5441c29d-3602-4898-b1a1-b77fa23b8e50" name="David Bowie" sortName="Bowie, David" tmid="734626">
#     <url>http://www.setlist.fm/setlists/david-bowie-6bd6ee66.html</url>
#   </artist>
#   <venue id="1bd63950" name="Verizon Wireless Arena">
#     <city id="5089178" name="Manchester" state="New Hampshire" stateCode="NH">
#       <coords lat="42.9956397" long="-71.4547891"/>
#       <country code="US" name="United States"/>
#     </city>
#     <url>http://www.setlist.fm/venue/verizon-wireless-arena-manchester-nh-usa-1bd63950.html</url>
#   </venue>
#   <sets>
#     <set>
#       <song name="Rebel Rebel"/>
#       <song name="Queen Bitch"/>
#       <song name="Cactus">
#         <cover disambiguation="" mbid="b6b2bb8d-54a9-491f-9607-7b546023b433" name="Pixies" sortName="Pixies" tmid="906179">
# ...

# %%
root = setree.getroot()
bla = setree.findall('sets/set/song')
print len(bla)
# Out:
# 25

# %%
songlist = []
if setree.findall('setlist').get('id') == '3d2d1ef':
    for song in setree.findall('sets/set/song'):
        print song.get('name')
        songlist.append(song.get('name'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-706a3fc7a33e> in <module>()
#       1 songlist = []
# ----> 2 if setree.findall('setlist').get('id') == '3d2d1ef':
#       3     for song in setree.findall('sets/set/song'):
#       4         print song.get('name')
#       5         songlist.append(song.get('name'))
#
# AttributeError: 'list' object has no attribute 'get'

# %%
songlist
# Out:
# ['Rebel Rebel',
#  'Queen Bitch',
#  'Cactus',
#  'Sister Midnight',
#  'New Killer Star',
#  'All the Young Dudes',
#  'China Girl',
#  'The Loneliest Guy',
#  'The Man Who Sold the World',
#  'Battle for Britain (The Letter)',
#  'Pablo Picasso',
#  'Heathen (The Rays)',
#  'The Supermen',
#  'Hallo Spaceboy',
#  'Under Pressure',
#  'Station to Station',
#  'Ashes to Ashes',
#  'Quicksand',
#  'Modern Love',
#  "I'm Afraid of Americans",
#  '"Heroes"',
#  'Diamond Dogs',
#  'Five Years',
#  'Suffragette City',
#  'Ziggy Stardust']

# %%
song

# %%
tree = etree.parse(response)
print etree.tostring(x, pretty_print = True)
# Out:
# <setlists itemsPerPage="20" page="1" total="1093">
#   <setlist eventDate="05-06-2016" id="4bfec76e" lastUpdated="2016-06-03T00:08:51.000+0000" tour="A Head Full of Dreams Tour" versionId="6ba1d6c2">
#     <artist disambiguation="" mbid="cc197bad-dc9c-440d-a5b5-d52ba2e14234" name="Coldplay" sortName="Coldplay" tmid="806431">
#       <url>http://www.setlist.fm/setlists/coldplay-3d6bde3.html</url>
#     </artist>
#     <venue id="43d71f37" name="Etihad Stadium">
#       <city id="2643123" name="Manchester" state="England" stateCode="ENG">
#         <coords lat="53.4809464283615" long="-2.23743438720703"/>
#         <country code="GB" name="United Kingdom"/>
#       </city>
#       <url>http://www.setlist.fm/venue/etihad-stadium-manchester-england-43d71f37.html</url>
#     </venue>
#     <sets/>
#     <url>http://www.setlist.fm/setlist/coldplay/2016/etihad-stadium-manchester-england-4bfec76e.html</url>
#   </setlist>
# ...

# %%
bla = tree.findall('setlist/sets/set/song')
print len(lst)
# Out:
# 394

# %%
for setlist in root.findall('setlist'):
    for venue in root.iter('venue'):
        print venue.attrib
        
    for song in root.iter('song'):
        print song.attrib
# Out:
# {'id': '43d71f37', 'name': 'Etihad Stadium'}
# {'id': '43d71f37', 'name': 'Etihad Stadium'}
# {'id': '4bd78fbe', 'name': 'Veltins-Arena'}
# {'id': '33d61499', 'name': 'Powderham Castle'}
# {'id': '5bd4b3cc', 'name': u'Estadi Ol\xedmpic Llu\xeds Companys'}
# {'id': '5bd4b3cc', 'name': u'Estadi Ol\xedmpic Llu\xeds Companys'}
# {'id': '4bd6cf42', 'name': 'Stade Charles-Ehrmann'}
# {'id': '63d79ed7', 'name': 'Amway Center'}
# {'id': '5bd73b68', 'name': 'Good Morning America'}
# {'id': '63d592a3', 'name': 'Late Show With Stephen Colbert'}
# {'id': '53d63be5', 'name': 'Foro Sol'}
# {'id': '53d63be5', 'name': 'Foro Sol'}
# {'id': '53d63be5', 'name': 'Foro Sol'}
# {'id': '63d636ff', 'name': u'Estadio El Camp\xedn'}
# {'id': '3bd70ca8', 'name': u'Est\xe1dio do Maracan\xe3'}
# {'id': '6bd41616', 'name': 'Allianz Parque'}
# {'id': '63d6762f', 'name': 'Estadio Nacional'}
# {'id': '63d622c3', 'name': 'Estadio Nacional'}
# {'id': '3d62153', 'name': 'Estadio Ciudad de La Plata'}
# ...

# %%
for item in tree.findall('setlist/sets/set/song'):
    print item.get('name')
# Out:
# O mio babbino caro
# A Head Full of Dreams
# Yellow
# Every Teardrop Is a Waterfall
# The Scientist
# Birds
# Paradise
# Everglow
# Lovers in Japan
# Everglow
# Magic
# Clocks
# Midnight
# Charlie Brown
# Hymn for the Weekend
# Fix You
# "Heroes"
# Viva la Vida
# Adventure of a Lifetime
# Kaleidoscope
# Don't Panic
# In My Place
# See You Soon
# Amazing Day
# A Sky Full of Stars
# Up&Up
# O (Reprise)
# A Head Full of Dreams
# Yellow
# Paradise
# Hymn for the Weekend
# Fix You
# Raspberry Beret
# Viva la Vida
# Adventure of a Lifetime
# The Scientist
# A Sky Full of Stars
# Up&Up
# O mio babbino caro
# A Head Full of Dreams
# Yellow
# Every Teardrop Is a Waterfall
# The Scientist
# Birds
# Paradise
# Everglow
# Ink
# Magic
# Clocks
# Midnight
# Charlie Brown
# Hymn for the Weekend
# Fix You
# "Heroes"
# Viva la Vida
# Adventure of a Lifetime
# Kaleidoscope
# Trouble
# Johnny B. Goode
# See You Soon
# Amazing Day
# A Sky Full of Stars
# Up&Up
# O (Reprise)
# O mio babbino caro
# ...

# %%
for item in tree.findall('setlist/venue'):    
    print item.get('name')
# Out:
# Etihad Stadium
# Etihad Stadium
# Veltins-Arena
# Powderham Castle
# Estadi Olímpic Lluís Companys
# Estadi Olímpic Lluís Companys
# Stade Charles-Ehrmann
# Amway Center
# Good Morning America
# Late Show With Stephen Colbert
# Foro Sol
# Foro Sol
# Foro Sol
# Estadio El Campín
# Estádio do Maracanã
# Allianz Parque
# Estadio Nacional
# Estadio Nacional
# Estadio Ciudad de La Plata
# Estadio Ciudad de La Plata

# %%
root = x.getroot()
root.getchildren()[0].getchildren()[2]
# Out:
# <Element url at 0x108528c68>

# %%
df = pd.DataFrame(columns=('venue', 'song'))
for i in range(0,4):
    obj = root.getchildren()[i].getchildren()
    row = dict(zip(['venue', 'song'], [obj[1].text, obj[2].text]))
    row_s = pd.Series(row)
    row_s.name = i
    df = df.append(row_s)
    
df
# Out:
#   venue song
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN

# %%
root.tag
# Out:
# 'setlists'

# %%
root.findall[".//neighbor[2]"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-ea4b051240b7> in <module>()
# ----> 1 root.findall[".//neighbor[2]"]
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
for song in root.findall('song name'):
    son = song.find('song name').text
    print son

# %%
import xml.etree.ElementTree as ET

stuff = ET.fromstring(response)
lst = stuff.findall('/setlist/sets/set/song')
lst
# for item in lst:
#     print item.find('song name').text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-8202c72a7a1c> in <module>()
#       1 import xml.etree.ElementTree as ET
#       2
# ----> 3 stuff = ET.fromstring(response)
#       4 lst = stuff.findall('/setlist/sets/set/song')
#       5 lst
#
# /Users/doa/anaconda/lib/python2.7/xml/etree/ElementTree.pyc in XML(text, parser)
#    1298     if not parser:
#    1299         parser = XMLParser(target=TreeBuilder())
# -> 1300     parser.feed(text)
#    1301     return parser.close()
#    1302
#
# /Users/doa/anaconda/lib/python2.7/xml/etree/ElementTree.pyc in feed(self, data)
#    1638     def feed(self, data):
#    1639         try:
# -> 1640             self._parser.Parse(data, 0)
#    1641         except self._error, v:
#    1642             self._raiseerror(v)
#
# TypeError: must be string or read-only buffer, not instance

# %%
df = pd.concat((pd.read_json(d) for d in data), axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-cf339f8ad4c0> in <module>()
# ----> 1 df = pd.concat((pd.read_json(d) for d in data), axis=0)
#
# /Users/doa/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     810                        keys=keys, levels=levels, names=names,
#     811                        verify_integrity=verify_integrity,
# --> 812                        copy=copy)
#     813     return op.get_result()
#     814
#
# /Users/doa/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     840             objs = [objs[k] for k in keys]
#     841         else:
# --> 842             objs = list(objs)
#     843
# ...

# %%
for line in response:
    data = json.loads(line)
    print data

# %%
for line in response:
    data = json.loads(line)
    print str(data['setlists']['setlist']['sets']['set']['song']['@name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-93f45aee114e> in <module>()
#       1 for line in response:
#       2     data = json.loads(line)
# ----> 3     print str(data['setlists']['setlist']['sets']['set']['song']['@name'])
#       4
#
# TypeError: list indices must be integers, not str

# %%
for line in data:
    for setlist in range(len(data['setlists']['setlist'])):
#         try:
            for sets in range(len(data['setlists']['setlist'][setlist]['sets']['set'])):
#                 try:
                    for song in range(len(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'])):
                        if data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name']:
                            print str(data["setlists"]["setlist"][setlist]["@eventDate"]), str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name'])
#                 except:
#                    pass
#         except:
#             pass

# %%
data
# Out:
# {u'setlists': {u'@itemsPerPage': u'20',
#   u'@page': u'1',
#   u'@total': u'1092',
#   u'setlist': [{u'@eventDate': u'04-06-2016',
#     u'@id': u'2bfecc2a',
#     u'@lastUpdated': u'2016-06-02T02:23:47.000+0000',
#     u'@tour': u'A Head Full of Dreams Tour',
#     u'@versionId': u'ba1e1de',
#     u'artist': {u'@disambiguation': u'',
#      u'@mbid': u'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#      u'@name': u'Coldplay',
#      u'@sortName': u'Coldplay',
#      u'@tmid': u'806431',
#      u'url': u'http://www.setlist.fm/setlists/coldplay-3d6bde3.html'},
#     u'sets': u'',
#     u'url': u'http://www.setlist.fm/setlist/coldplay/2016/etihad-stadium-manchester-england-2bfecc2a.html',
#     u'venue': {u'@id': u'43d71f37',
#      u'@name': u'Etihad Stadium',
#      u'city': {u'@id': u'2643123',
#       u'@name': u'Manchester',
#       u'@state': u'England',
#       u'@stateCode': u'ENG',
#       u'coords': {u'@lat': u'53.4809464283615',
#        u'@long': u'-2.23743438720703'},
# ...

# %%
result = pd.json_normalize(response, '@eventDate', ['@tour', '@sortname', 'sets'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-c1d61930e196> in <module>()
# ----> 1 result = pd.json_normalize(data, '@eventDate', ['@tour', '@sortname', 'sets'])
#
# AttributeError: 'module' object has no attribute 'json_normalize'

# %%
f = open('Coldplay' + 'ConcertsTimeline.csv', 'wt')
writer = csv.writer(f, delimiter=';')
writer.writerow( 
               (
               'eventID',
               'artist',
               'eventdate',
               'tourname',
               'venue',
               'venue_id',
               'city',
               'city_id',
               'city_lat',
               'city_lon',
               'state',
               'state_id',
               'country',
               'country_id',
               'setlist'
               )
               )

# %%
# Get total number of shows
totalshows = int(data['setlists']['@total'])

# Total Number of Pages needed to load
pages = int(totalshows/20)

# %%
data
# Out:
# {u'setlists': {u'@itemsPerPage': u'20',
#   u'@page': u'1',
#   u'@total': u'1092',
#   u'setlist': [{u'@eventDate': u'04-06-2016',
#     u'@id': u'2bfecc2a',
#     u'@lastUpdated': u'2016-06-02T02:23:47.000+0000',
#     u'@tour': u'A Head Full of Dreams Tour',
#     u'@versionId': u'ba1e1de',
#     u'artist': {u'@disambiguation': u'',
#      u'@mbid': u'cc197bad-dc9c-440d-a5b5-d52ba2e14234',
#      u'@name': u'Coldplay',
#      u'@sortName': u'Coldplay',
#      u'@tmid': u'806431',
#      u'url': u'http://www.setlist.fm/setlists/coldplay-3d6bde3.html'},
#     u'sets': u'',
#     u'url': u'http://www.setlist.fm/setlist/coldplay/2016/etihad-stadium-manchester-england-2bfecc2a.html',
#     u'venue': {u'@id': u'43d71f37',
#      u'@name': u'Etihad Stadium',
#      u'city': {u'@id': u'2643123',
#       u'@name': u'Manchester',
#       u'@state': u'England',
#       u'@stateCode': u'ENG',
#       u'coords': {u'@lat': u'53.4809464283615',
#        u'@long': u'-2.23743438720703'},
# ...

# %%
result = pd.json_normalize(data, 'sets')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-051aa9e52b70> in <module>()
# ----> 1 result = pd.json_normalize(data, 'sets')
#
# AttributeError: 'module' object has no attribute 'json_normalize'

# %%
for page in range(1,pages):
    data = urllib2.urlopen('http://api.setlist.fm/rest/0.1/artist/' + 'cc197bad-dc9c-440d-a5b5-d52ba2e14234' + '/setlists.json?p=' + str(page))


    for line in data:
        data1 = json.loads(line)
        print data
# Out:
# <addinfourl at 4476350760 whose fp = <socket._fileobject object at 0x10a7a76d0>>
# <addinfourl at 4475113128 whose fp = <socket._fileobject object at 0x10a7a7650>>
# <addinfourl at 4476351912 whose fp = <socket._fileobject object at 0x10a7a7bd0>>
# <addinfourl at 4476353496 whose fp = <socket._fileobject object at 0x10a7a7650>>
# <addinfourl at 4476350832 whose fp = <socket._fileobject object at 0x10a7a7bd0>>
# <addinfourl at 4475112480 whose fp = <socket._fileobject object at 0x10a7a7650>>
# <addinfourl at 4476351984 whose fp = <socket._fileobject object at 0x10a7a7bd0>>
# <addinfourl at 4470737952 whose fp = <socket._fileobject object at 0x10a7a7650>>
# <addinfourl at 4475135256 whose fp = <socket._fileobject object at 0x10a7a7bd0>>
# <addinfourl at 4475110824 whose fp = <socket._fileobject object at 0x10a7a7650>>
# <addinfourl at 4475111544 whose fp = <socket._fileobject object at 0x10a7a77d0>>
# <addinfourl at 4475110608 whose fp = <socket._fileobject object at 0x10a7a7850>>
# ...

# %%
data
# Out:
# <addinfourl at 4470832520 whose fp = <socket._fileobject object at 0x10a7a7850>>

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
test123 = pd.read_json(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-70ccae1281a4> in <module>()
# ----> 1 test123 = pd.read_json(data)
#
# /Users/doa/anaconda/lib/python2.7/site-packages/pandas/io/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     208         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     209                           keep_default_dates, numpy, precise_float,
# --> 210                           date_unit).parse()
#     211
#     212     if typ == 'series' or obj is None:
#
# /Users/doa/anaconda/lib/python2.7/site-packages/pandas/io/json.py in parse(self)
#     276
#     277         else:
# --> 278             self._parse_no_numpy()
#     279
#     280         if self.obj is None:
#
# ...

# %%
result = json_normalize(data,)
# Out:
#                                                         setlists
# @itemsPerPage                                                 20
# @page                                                          1
# @total                                                      1092
# setlist        [{u'artist': {u'@sortName': u'Coldplay', u'url...

# %%
setlist = []
for line in data:
    for setlist in range(len(data['setlists']['setlist'])):
#         try:
            for sets in range(len(data['setlists']['setlist'][setlist]['sets']['set'])):
#                 try:
                    for song in range(len(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'])):
                        if data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name']:
                            print str(data["setlists"]["setlist"][setlist]["@eventDate"]), str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name'])
#                 except:
#                    pass
#         except:
#             pass
# Out:
# 13-03-2000 1 Don't Panic
# 13-03-2000 2 Shiver
# 13-03-2000 3 Spies
# 13-03-2000 4 Sparks
# 13-03-2000 5 Yellow
# 13-03-2000 6 Trouble
# 13-03-2000 7 Parachutes
# 13-03-2000 8 High Speed
# 13-03-2000 9 We Never Change
# 13-03-2000 10 Everything's Not Lost
# 13-03-2000 11 Help Is Around the Corner
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-0cf316984b3e> in <module>()
#       6 #                 try:
#       7                     for song in range(len(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'])):
# ----> 8                         if data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name']:
#       9                             print str(data["setlists"]["setlist"][setlist]["@eventDate"]), str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name'])
# ...

# %%
print setlist
# Out:
# 19

# %%
for line in data:
    for setlist in range(len(data['setlists']['setlist'])):
        for sets in range(len(data['setlists']['setlist'][setlist]['sets']['set'])):
            for song in range(len(data['setlists']['setlist'][setlist]['sets']['set'][sets])):
                try:
                    print str(data["setlists"]["setlist"][setlist]["@eventDate"]), str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name'])
                except:
                    print str(data["setlists"]["setlist"][setlist]["@eventDate"]), "encore" + str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['encore'][sets]['song'][song]['@name'])
# Out:
#  13-03-2000 1 Don't Panic
# 13-03-2000 13-03-2000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-02a7a3bbb776> in <module>()
#       6                     print str(data["setlists"]["setlist"][setlist]["@eventDate"]), str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['set'][sets]['song'][song]['@name'])
#       7                 except:
# ----> 8                     print str(data["setlists"]["setlist"][setlist]["@eventDate"]), "encore" + str(song + 1) + " " + str(data['setlists']['setlist'][setlist]['sets']['encore'][sets]['song'][song]['@name'])
#
# KeyError: 'encore'

# %%
    # Read .json file line per line
    for line in data:
        data = json.loads(line)

        for i in range(len(data['setlists']['setlist'])):
            writer.writerow(
                           (
                           # Event ID
                           str(data["setlists"]["setlist"][i]["@id"]),
                           # Artist
                           str(data['setlists']['setlist'][i]["artist"]["@name"]),
                           # Eventdate
                           str(data["setlists"]["setlist"][i]["@eventDate"]),
                           # TourName
                           unicode(data["setlists"]["setlist"][i].get("@tour")).encode('utf-8'),
                           # Venue
                           unicode(data["setlists"]["setlist"][i]["venue"].get("@name")).encode('utf-8'),
                           # Venue ID
                           str(data["setlists"]["setlist"][i]["venue"].get("@id")),
                           # City
                           unicode(data["setlists"]["setlist"][i]["venue"]["city"].get("@name")).encode('utf-8'),
                           # City ID
                           str(data["setlists"]["setlist"][i]["venue"]["city"].get("@id")),
                           # City Latitude
                           float(data["setlists"]["setlist"][i]["venue"]["city"]["coords"].get("@lat")),
                           # City Longitude
                           float(data["setlists"]["setlist"][i]["venue"]["city"]["coords"].get("@long")),
                           # State
                           unicode(data["setlists"]["setlist"][i]["venue"]["city"].get("@state")).encode('utf-8'),
                           # State Code
                           str(data["setlists"]["setlist"][i]["venue"]["city"].get("@stateCode")),
                           # Country
                           unicode(data["setlists"]["setlist"][i]["venue"]["city"]["country"].get("@name")).encode('utf-8'),
                           # Country Code
                           unicode(data["setlists"]["setlist"][i]["venue"]["city"]["country"].get("@code")).encode('utf-8')
                           # Setlist
                           str(data["setlists"]["sets"][i]["@name"]))))
# Out:
#   File "<ipython-input-34-18c1a1bbabbe>", line 37
#     str(data["setlists"]["sets"][i]["@name"]))))
#       ^
# SyntaxError: invalid syntax

# %%
denemedata = pd.DataFrame.from_csv('ColdplayConcertsTimeline.csv', parse_dates=True)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-307-45f6c77e2de2> in <module>()
# ----> 1 denemedata = pd.DataFrame.from_csv('ColdplayConcertsTimeline.csv', parse_dates=True)
#
# /Users/doa/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1175                           parse_dates=parse_dates, index_col=index_col,
#    1176                           encoding=encoding, tupleize_cols=tupleize_cols,
# -> 1177                           infer_datetime_format=infer_datetime_format)
#    1178
#    1179     def to_sparse(self, fill_value=None, kind='block'):
#
# ...

# %%
import discogs_client as dc

# %%
dir(discogs_client.Artist)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'aliases',
#  'data_quality',
#  'delete',
#  'fetch',
#  'groups',
#  'id',
#  'images',
#  'members',
#  'name',
#  'name_variations',
#  'profile',
#  'real_name',
#  'refresh',
#  'releases',
#  'repr_str',
#  'save',
#  'url',
#  'urls']

# %%
d = dc.Client('ExampleApplication/0.1')

# %%
d.set_consumer_key('aCLPtfNbXjreFFLQobgX', 'EfDUNPBkIKVsCeWYoMUtJnalPYpPXWii')

# %%
d.get_authorize_url()
# Out:
# (u'PKGNuTPnPiZsBJPlmPWLyzWoREZdUItbCpHUxdZt',
#  u'DqZNULWnxpLebVzVygZnLEqvtiuqsArYUlGFbRaU',
#  u'https://www.discogs.com/oauth/authorize?oauth_token=PKGNuTPnPiZsBJPlmPWLyzWoREZdUItbCpHUxdZt')

# %%
d.get_access_token('LToNnPiTyJ')
# Out:
# (u'jbJOzZaqzNMDQmUePIRxgYEXTEICvXoZxIuSsuoy',
#  u'QTQsqZVTFldRHyFcwQQpRyPsKIrWxfkdZrbGClKd')

# %%
me = d.identity()

# %%
"I'm {0} ({1}) from {2}.".format(me.name, me.username, me.location)
# Out:
# "I'm  (dogaker) from ."

# %%
results = d.search('iron maiden', type='artist')

# %%
results[0].id

# results[0].releases[1].main_release

# for i in range (0, 1340):
#     try: 
#         print results[0].releases[i].main_release
#     except:
#         continue
# Out:
# 251595

# %%
artist = d.artist(251595)

# %%
dir(artist.releases)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_filters',
#  '_invalidate',
#  '_list_key',
#  '_load_pagination_info',
#  '_num_items',
#  '_num_pages',
#  '_pages',
#  '_per_page',
#  '_sort_key',
#  '_sort_order',
#  '_transform',
#  '_url_for_page',
#  'client',
#  'count',
#  'filter',
#  'page',
#  'pages',
#  'per_page',
#  'sort',
#  'url']

# %%
dir(artist.releases[0].versions)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_filters',
#  '_invalidate',
#  '_list_key',
#  '_load_pagination_info',
#  '_num_items',
#  '_num_pages',
#  '_pages',
#  '_per_page',
#  '_sort_key',
#  '_sort_order',
#  '_transform',
#  '_url_for_page',
#  'class_',
#  'client',
#  'count',
#  'filter',
#  'page',
#  'pages',
#  'per_page',
#  'sort',
#  'url']

# %%
artist.id
# Out:
# 251595

# %%
artist == dctest.artist(251595)
# Out:
# True

# %%
artist = dctest.artist(251595)

# %%
print artist
# Out:
# <Artist 251595 u'Iron Maiden'>

# %%
dir(artist.releases)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_filters',
#  '_invalidate',
#  '_list_key',
#  '_load_pagination_info',
#  '_num_items',
#  '_num_pages',
#  '_pages',
#  '_per_page',
#  '_sort_key',
#  '_sort_order',
#  '_transform',
#  '_url_for_page',
#  'client',
#  'count',
#  'filter',
#  'page',
#  'pages',
#  'per_page',
#  'sort',
#  'url']

# %%
release = dctest.master(18742)

# %%
release.main_release
# Out:
# <Release 1466299 u'The Number Of The Beast'>
